# %%
import torch
from ultralytics import YOLO
import shutil
import pandas as pd

# %%
print("CUDA:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
torch.cuda.empty_cache()
# Out:
# CUDA: True
# GPU: NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %%
model = YOLO(
    "/home/muliaandiki/project/NutriPlate/preprocessing/runs/train/dietary_yolov8s/weights/best.pt"
)

model.train(
    data="/home/muliaandiki/project/NutriPlate/preprocessing/data_merged/data.yaml",
    epochs=40,
    imgsz=640,
    batch=4,
    optimizer="AdamW",
    patience=15,
    device=0,
    project="/home/muliaandiki/project/NutriPlate/preprocessing/runs/train",
    name="dietary_yolov8s_v26",
    workers=4
)
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.3 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 5804MiB)
# ...

# %%
from ultralytics import YOLO

DATASET_PATH = "/home/muliaandiki/project/NutriPlate/preprocessing/data/Dietary App Segment.v1i.yolov8"
DATA_YAML = f"{DATASET_PATH}/data.yaml"

modelEval = YOLO(
    "/home/muliaandiki/project/NutriPlate/preprocessing/runs/train/dietary_yolov8s_v26/weights/best.pt"
)

metrics = modelEval.val(
    data=DATA_YAML,
    imgsz=640,
    device=0,
    plots=True,
    save_dir="/home/muliaandiki/project/NutriPlate/preprocessing/runs/val_full_26"
)

print(metrics)
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.3 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 5804MiB)
# Model summary (fused): 73 layers, 11,135,646 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3996.9±812.6 MB/s, size: 60.0 KB)
# val: Scanning /home/muliaandiki/project/NutriPlate/preprocessing/data/Dietary App Segment.v1i.yolov8/valid/labels.cache... 678 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 678/678 316.0Mit/s 0.0s
# val: /home/muliaandiki/project/NutriPlate/preprocessing/data/Dietary App Segment.v1i.yolov8/valid/images/Image_43_jpg.rf.04a45ce90074bb4924a043bb0c08f5db.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 5.2it/s 8.3s0.2s
#                    all        678       1709      0.509     0.0351     0.0682     0.0623
#             ayam bakar         13         25          1          0          0          0
# ...
