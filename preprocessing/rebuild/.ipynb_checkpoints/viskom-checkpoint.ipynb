# %%
# Install dependencies
# !pip install -U ultralytics
# !pip install opencv-python-headless
# !pip install albumentations
# !pip install labelImg
# !pip install deep-sort-realtime
# Out:
# Requirement already satisfied: ultralytics in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (8.3.240)
# Requirement already satisfied: numpy>=1.23.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from ultralytics) (2.7.1+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from ultralytics) (0.22.1+cu118)
# Requirement already satisfied: psutil>=5.8.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from ultralytics) (7.1.3)
# Requirement already satisfied: polars>=0.20.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from ultralytics) (1.36.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.36.1 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from polars>=0.20.0->ultralytics) (1.36.1)
# Requirement already satisfied: six>=1.5 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.8.86)
# Requirement already satisfied: triton==3.3.1 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: opencv-python-headless in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from opencv-python-headless) (2.2.6)
# Requirement already satisfied: albumentations in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (2.0.8)
# Requirement already satisfied: numpy>=1.24.4 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from albumentations) (2.2.6)
# Requirement already satisfied: scipy>=1.10.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from albumentations) (1.16.3)
# Requirement already satisfied: PyYAML in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from albumentations) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from albumentations) (2.12.5)
# Requirement already satisfied: albucore==0.0.24 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from albumentations) (4.12.0.88)
# Requirement already satisfied: stringzilla>=3.10.4 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from albucore==0.0.24->albumentations) (4.4.0)
# Requirement already satisfied: simsimd>=5.9.2 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from albucore==0.0.24->albumentations) (6.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from pydantic>=2.9.2->albumentations) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from pydantic>=2.9.2->albumentations) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from pydantic>=2.9.2->albumentations) (0.4.2)
# Requirement already satisfied: labelImg in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (1.8.6)
# Requirement already satisfied: pyqt5 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from labelImg) (5.15.11)
# Requirement already satisfied: lxml in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from labelImg) (6.0.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from pyqt5->labelImg) (12.17.2)
# Requirement already satisfied: PyQt5-Qt5<5.16.0,>=5.15.2 in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from pyqt5->labelImg) (5.15.18)
# Requirement already satisfied: deep-sort-realtime in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (1.3.2)
# Requirement already satisfied: numpy in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from deep-sort-realtime) (2.2.6)
# Requirement already satisfied: scipy in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from deep-sort-realtime) (1.16.3)
# Requirement already satisfied: opencv-python in /home/muliaandiki/project/NutriPlate/preprocessing/yolov_env/lib/python3.12/site-packages (from deep-sort-realtime) (4.12.0.88)

# %%
import cv2
import torch
from ultralytics import YOLO
from collections import defaultdict

# %%
print("CUDA:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
torch.cuda.empty_cache()
# Out:
# CUDA: True
# GPU: NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %%
model = YOLO("yolov8n.pt")
model.to("cuda")
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): Upsample(scale_factor=2.0, mode='nearest')
#       (11): Concat()
#       (12): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (13): Upsample(scale_factor=2.0, mode='nearest')
#       (14): Concat()
#       (15): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (16): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (17): Concat()
#       (18): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (19): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (20): Concat()
#       (21): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (22): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )

# %%
video_path = "video.mp4"   # ganti sesuai path kamu
cap = cv2.VideoCapture(video_path)

assert cap.isOpened(), "Video tidak bisa dibuka!"

# %%
fps = cap.get(cv2.CAP_PROP_FPS)
if fps == 0 or fps is None:
    fps = 25  # fallback aman

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

print(f"FPS: {fps}, Size: {width}x{height}")

# %%
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(
    "output_tracking.mp4",
    fourcc,
    fps,
    (width, height)
)

# %%
track_history = defaultdict(list)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model.track(
        frame,
        persist=True,
        conf=0.4,
        classes=[0],   # person
        tracker="bytetrack.yaml"
    )

    if results[0].boxes.id is not None:
        boxes = results[0].boxes.xyxy.cpu()
        track_ids = results[0].boxes.id.cpu().numpy()

        for box, track_id in zip(boxes, track_ids):
            x1, y1, x2, y2 = map(int, box)
            cx, cy = (x1 + x2)//2, (y1 + y2)//2

            track_history[track_id].append((cx, cy))

            # Bounding box + ID
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)
            cv2.putText(
                frame, f"ID {track_id}",
                (x1, y1 - 10),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6, (0,255,0), 2
            )

            # Trajectory
            for i in range(1, len(track_history[track_id])):
                cv2.line(
                    frame,
                    track_history[track_id][i-1],
                    track_history[track_id][i],
                    (255, 0, 0), 2
                )

    out.write(frame)
# Out:
# 0: 384x640 7 persons, 43.7ms
# Speed: 2.1ms preprocess, 43.7ms inference, 19.9ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[38], line 55
#      47     for i in range(1, len(track_history[track_id])):
#      48         cv2.line(
#      49             frame,
#      50             track_history[track_id][i - 1],
#      51             track_history[track_id][i],
#      52             (255, 0, 0), 2
#      53         )
# ---> 55 cv2.imshow("YOLOv8 + DeepSORT | Person Tracking", frame)
#      57 if cv2.waitKey(delay) & 0xFF == ord('q'):
#      58     break
#
# error: OpenCV(4.12.0) /io/opencv/modules/highgui/src/window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
cap.release()
out.release()
print("Selesai! Output tersimpan sebagai output_tracking.mp4")
